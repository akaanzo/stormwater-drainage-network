# %% [markdown]
# # Sintesi della verifica delle condotte
# ---
# Franzoi - Rebellato - 2019-06-08

# %%
import os
import pandas as pd
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
os.getcwd()
# Out:
# 'C:\\Users\\anzo5\\Desktop\\fognatura'

# %%
path = r'conduits\\csv'
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
    
data = pd.concat(li, axis=0, ignore_index = True)
data = data.set_index('Condotta'); data
# Out:
#           Portata [l/s]  Pendenza  Diametro         G       theta        Rh  \
# Condotta
# c00            2396.294  0.008000     1.025  0.748977  239.729552  0.309144
# c01             518.562  0.019925     0.500  0.707067  228.929584  0.148586
# c02             452.471  0.020917     0.500  0.633323  210.929599  0.142452
# c03             302.252  0.026677     0.400  0.663318  218.129559  0.116218
# c04             162.443  0.026834     0.400  0.446562  167.729556  0.092740
# c05              72.400  0.025993     0.218  0.775712  246.929569  0.066134
# c06            1929.646  0.013963     0.853  0.748977  239.729552  0.257268
# c07            1387.876  0.008500     0.800  0.788678  250.529577  0.243124
# c08            1330.824  0.010000     0.800  0.602801  203.729583  0.222635
# c09            1307.339  0.016132     0.800  0.602801  203.729583  0.222635
# c10            1016.643  0.015757     0.690  0.663318  218.129559  0.200476
# c11             963.720  0.004737     0.853  0.663318  218.129559  0.247835
# c12             211.837  0.035638     0.344  0.618121  207.329591  0.096911
# c13             162.918  0.018115     0.344  0.648394  214.529551  0.099019
# c14             127.293  0.026503     0.273  0.735235  236.129601  0.082000
# c15              71.126  0.004935     0.300  0.748977  239.729552  0.090481
# c16             167.021  0.021797     0.344  0.618121  207.329591  0.096911
# c17             164.960  0.018006     0.344  0.663318  218.129559  0.099948
# c18             264.679  0.019795     0.400  0.663318  218.129559  0.116218
# c19             503.992  0.003003     0.690  0.735235  236.129601  0.207253
# c20             545.944  0.038641     0.427  0.788678  250.529577  0.129767
# c21             157.389  0.024600     0.300  0.735235  236.129601  0.090110
# c22             297.025  0.025576     0.400  0.663318  218.129559  0.116218
# c23             473.924  0.003000     0.690  0.707067  228.929584  0.205048
# c24             584.799  0.004000     0.690  0.735235  236.129601  0.207253
# c25             793.327  0.007000     0.690  0.748977  239.729552  0.208107
# c26             145.906  0.028896     0.300  0.663318  218.129559  0.087164
# c27              90.109  0.005000     0.344  0.678082  221.729567  0.100792
# c28             152.802  0.001345     0.500  0.775712  246.929569  0.151684
# c29             288.528  0.001000     0.690  0.735235  236.129601  0.207253
#
#                 tau Criterio di autopulizia (tau>2 Pa)
# Condotta
# c00       24.261613                        Verificato!
# c01       29.043163                        Verificato!
# c02       29.230547                        Verificato!
# c03       30.414477                        Verificato!
# c04       24.413068                        Verificato!
# c05       16.863706                        Verificato!
# c06       35.239812                        Verificato!
# c07       20.272899                        Verificato!
# c08       21.840484                        Verificato!
# c09       35.233069                        Verificato!
# c10       30.988888                        Verificato!
# c11       11.516905                        Verificato!
# c12       33.881029                        Verificato!
# c13       17.596537                        Verificato!
# c14       21.319604                        Verificato!
# c15        4.380405                        Verificato!
# c16       20.722397                        Verificato!
# c17       17.654648                        Verificato!
# c18       22.568301                        Verificato!
# c19        6.105565                        Verificato!
# c20       49.190719                        Verificato!
# c21       21.745921                        Verificato!
# c22       29.159225                        Verificato!
# c23        6.034564                        Verificato!
# c24        8.132621                        Verificato!
# c25       14.290682                        Verificato!
# c26       24.708271                        Verificato!
# c27        4.943838                        Verificato!
# c28        2.001393                        Verificato!
# c29        2.033155                        Verificato!

# %% [markdown]
# | Condotta | Allineamento | Nodo |
# | -------- | ------------ | ---- |
# | c00      | fondo        | n00|
# | c01      |     cielo    | n00  |
# | c02      | fondo        | n01 e n19  |
# | c03      | cielo        | n01  |
# | c04      | fondo        | n20 e n12  |
# | c05      | cielo        | n20  |
# | c06      | cielo        | n00  |
# | c07      | fondo        | n27 e n09  |
# | c08      | fondo        | n28 e n27  |
# | c09      | fondo        | n08 e n28  |
# | c10      | fondo        | n25 e n08  |
# | c11      | fondo        | n07 e n25  |
# | c12      | cielo        | n07  |
# | c13      | fondo        | n06 e n23  |
# | c14      | cielo        | n05 e n23  |
# | c15      | fondo        | n22 e n05  |
# | c16      | fondo        | n03 e n16  |
# | c17      | fondo        | n16 e n13  |
# | c18      | cielo        | n10  |
# | c19      | fondo        | n10 e n29  |
# | c20      |     cielo    | n09  |
# | c21      | cielo        | n17  |
# | c22      | cielo        | n14  |
# | c23      | fondo        | n14 e n24  |
# | c24      | fondo        | n24 e n15  |
# | c25      |     cielo    | n07  |
# | c26      | cielo        | n15  |
# | c27      | fondo        | n21 e n03  |
# | c28      | cielo        | n11  |
# | c29      |     fondo    | n11 e n08  |

# %% [markdown]
# ---
